# %%
import requests
import threading
import time
from queue import Queue
import pandas as pd
from urllib.parse import urljoin
from datetime import datetime

# %%
# --- Config ---
BASE_URL = "https://jiji.com.et/api_web/v1/listing"
BASE_SITE = "https://jiji.com.et"
CATEGORY_SLUG = "health-and-beauty"
NUM_WORKERS = 7
DELAY_SECONDS = 2
LSMID = "1768997666323"
date = datetime.now()

# --- Shared variables ---
next_page = 1
page_lock = threading.Lock()

seen_guids = set()
seen_lock = threading.Lock()

all_products = []
products_lock = threading.Lock()

stop_event = threading.Event()

# --- Worker function ---
def worker(worker_id):
    global next_page
    while not stop_event.is_set():
        # Get the next page safely
        with page_lock:
            page = next_page
            next_page += 1

        params = {
            "slug": CATEGORY_SLUG,
            "init_page": "true" if page == 1 else "false",
            "page": page,
            "webp": "false",
            "lsmid": LSMID
        }

        try:
            resp = requests.get(BASE_URL, params=params, timeout=10)
            resp.raise_for_status()
            data = resp.json()
        except Exception as e:
            print(f"[Worker {worker_id}] Request failed on page {page}: {e}")
            time.sleep(DELAY_SECONDS)
            continue

        adverts = data.get("adverts_list", {}).get("adverts", [])

        # Stop if no adverts
        if not adverts:
            print(f"[Worker {worker_id}] Page {page} has no adverts, stopping scraper")
            stop_event.set()
            break

        new_items = 0
        for item in adverts:
            guid = item.get("guid")
            if not guid:
                continue

            # Deduplicate
            with seen_lock:
                if guid in seen_guids:
                    continue
                seen_guids.add(guid)

            images = [img.get("url") for img in item.get("images", []) if img.get("url")]

            product = {
                "title": item.get("title"),
                "category": item.get("category_name"),
                "category_id": item.get("category_id"),
                "description": item.get("details") or item.get("short_description"),
                "price": item.get("price_obj", {}).get("value"),
                "price_text": item.get("price_title"),
                "currency": item.get("price_obj", {}).get("currency") or "ETB",
                "condition": next((a.get("value") for a in item.get("attrs", []) if a.get("name")=="Condition"), None),
                "region": item.get("region_name"),
                "region_id": item.get("region_id"),
                "city": item.get("region_parent_name"),
                "url": urljoin(BASE_SITE, item.get("url", "")),
                "guid": guid,
                "images": images,
                "count_images": item.get("count_images"),
                "user_id": item.get("user_id"),
                "status": item.get("status"),
                "scrape_date": date
            }

            with products_lock:
                all_products.append(product)
            new_items += 1

        print(f"[Worker {worker_id}] Page {page} scraped, {new_items} new items")
        time.sleep(DELAY_SECONDS)

# --- Start threads ---
threads = []
for i in range(NUM_WORKERS):
    t = threading.Thread(target=worker, args=(i+1,))
    t.start()
    threads.append(t)

# Wait for all threads to finish
for t in threads:
    t.join()

# --- Save results ---
df = pd.DataFrame(all_products)
df.to_json("jiji_health_and_beauty.jsonl", orient="records", lines=True, index=False)
print(f"Scraping completed: {len(all_products)} products collected")
# Out:
# [Worker 2] Page 2 scraped, 20 new items
# [Worker 6] Page 6 scraped, 20 new items
# [Worker 4] Page 4 scraped, 20 new items
# [Worker 5] Page 5 scraped, 20 new items
# [Worker 7] Page 7 scraped, 20 new items
# [Worker 3] Page 3 scraped, 20 new items
# [Worker 1] Page 1 scraped, 20 new items
# [Worker 6] Page 9 scraped, 20 new items
# [Worker 5] Page 11 scraped, 20 new items
# [Worker 2] Page 8 scraped, 20 new items
# [Worker 4] Page 10 scraped, 20 new items
# [Worker 3] Page 13 scraped, 20 new items
# [Worker 7] Page 12 scraped, 20 new items
# [Worker 1] Page 14 scraped, 20 new items
# [Worker 5] Page 16 scraped, 20 new items[Worker 4] Page 18 scraped, 20 new items
#
# [Worker 2] Page 17 scraped, 20 new items
# [Worker 6] Page 15 scraped, 20 new items
# [Worker 3] Page 19 scraped, 20 new items
# [Worker 7] Page 20 scraped, 20 new items
# [Worker 1] Page 21 scraped, 20 new items
# [Worker 6] Page 25 scraped, 20 new items
# [Worker 5] Page 23 scraped, 20 new items
# [Worker 3] Page 26 scraped, 20 new items
# [Worker 7] Page 27 scraped, 20 new items
# [Worker 2] Page 24 scraped, 19 new items
# [Worker 1] Page 28 scraped, 20 new items
# [Worker 4] Page 22 scraped, 20 new items
# [Worker 6] Page 29 scraped, 20 new items
# [Worker 5] Page 30 scraped, 20 new items
# [Worker 7] Page 32 scraped, 20 new items
# [Worker 3] Page 31 scraped, 20 new items
# [Worker 1] Page 34 scraped, 20 new items
# [Worker 2] Page 33 scraped, 20 new items
# [Worker 4] Page 35 scraped, 20 new items
# [Worker 5] Page 37 scraped, 20 new items
# [Worker 6] Page 36 scraped, 20 new items
# [Worker 7] Page 38 scraped, 20 new items
# [Worker 3] Page 39 scraped, 20 new items
# [Worker 1] Page 40 scraped, 20 new items[Worker 2] Page 41 scraped, 20 new items
#
# [Worker 4] Page 42 scraped, 20 new items
# [Worker 6] Page 44 scraped, 20 new items
# [Worker 7] Page 45 scraped, 20 new items
# [Worker 3] Page 46 scraped, 20 new items
# [Worker 5] Page 43 scraped, 20 new items
# [Worker 2] Page 47 scraped, 20 new items
# [Worker 1] Page 48 scraped, 20 new items
# [Worker 4] Page 49 scraped, 20 new items
# [Worker 3] Page 52 scraped, 20 new items
# [Worker 7] Page 51 scraped, 20 new items
# [Worker 5] Page 53 scraped, 20 new items
# [Worker 6] Page 50 scraped, 20 new items
# [Worker 1] Page 55 scraped, 20 new items
# [Worker 2] Page 54 scraped, 20 new items
# [Worker 4] Page 56 scraped, 20 new items
# [Worker 6] Page 60 scraped, 20 new items
# [Worker 3] Page 57 scraped, 20 new items
# [Worker 7] Page 58 scraped, 20 new items
# [Worker 5] Page 59 scraped, 20 new items
# [Worker 2] Page 62 scraped, 20 new items
# [Worker 1] Page 61 scraped, 20 new items
# [Worker 4] Page 63 scraped, 20 new items
# [Worker 6] Page 64 scraped, 20 new items
# [Worker 3] Page 65 scraped, 20 new items
# [Worker 7] Page 66 scraped, 20 new items
# [Worker 5] Page 67 scraped, 20 new items
# [Worker 2] Page 68 scraped, 20 new items
# [Worker 1] Page 69 scraped, 20 new items
# [Worker 4] Page 70 scraped, 20 new items
# [Worker 3] Page 72 scraped, 20 new items
# [Worker 6] Page 71 scraped, 20 new items
# [Worker 7] Page 73 scraped, 20 new items
# [Worker 5] Page 74 scraped, 20 new items
# [Worker 2] Page 75 scraped, 20 new items
# [Worker 1] Page 76 scraped, 20 new items
# [Worker 4] Page 77 scraped, 20 new items
# [Worker 6] Page 79 scraped, 20 new items
# [Worker 7] Page 80 scraped, 20 new items
# [Worker 3] Page 78 scraped, 20 new items
# [Worker 5] Page 81 scraped, 20 new items
# [Worker 2] Page 82 scraped, 20 new items
# [Worker 1] Page 83 scraped, 20 new items
# [Worker 4] Page 84 scraped, 20 new items
# [Worker 7] Page 86 scraped, 20 new items[Worker 6] Page 85 scraped, 20 new items
#
# [Worker 3] Page 87 scraped, 20 new items
# [Worker 2] Page 89 scraped, 20 new items
# [Worker 5] Page 88 scraped, 20 new items
# [Worker 1] Page 90 scraped, 20 new items
# [Worker 4] Page 91 scraped, 20 new items
# [Worker 7] Page 92 scraped, 19 new items
# [Worker 6] Page 93 scraped, 20 new items
# [Worker 3] Page 94 scraped, 20 new items
# [Worker 2] Page 95 scraped, 20 new items
# [Worker 1] Page 97 scraped, 20 new items
# [Worker 5] Page 96 scraped, 20 new items
# [Worker 4] Page 98 scraped, 20 new items
# [Worker 7] Page 99 scraped, 20 new items
# [Worker 6] Page 100 scraped, 20 new items
# [Worker 3] Page 101 scraped, 19 new items
# [Worker 1] Page 103 scraped, 20 new items
# [Worker 2] Page 102 scraped, 20 new items
# [Worker 5] Page 104 scraped, 20 new items
# [Worker 4] Page 105 scraped, 20 new items
# [Worker 7] Page 106 scraped, 20 new items
# [Worker 6] Page 107 scraped, 20 new items
# [Worker 3] Page 108 scraped, 20 new items
# [Worker 5] Page 111 scraped, 20 new items
# [Worker 1] Page 109 scraped, 20 new items
# [Worker 2] Page 110 scraped, 20 new items
# [Worker 4] Page 112 scraped, 20 new items
# [Worker 3] Page 115 scraped, 20 new items
# [Worker 6] Page 114 scraped, 20 new items
# [Worker 7] Page 113 scraped, 20 new items
# [Worker 1] Page 117 scraped, 20 new items
# [Worker 5] Page 116 scraped, 20 new items
# [Worker 2] Page 118 scraped, 20 new items
# [Worker 4] Page 119 scraped, 20 new items
# [Worker 6] Page 121 scraped, 20 new items
# [Worker 7] Page 122 scraped, 20 new items
# [Worker 3] Page 120 scraped, 20 new items
# [Worker 1] Page 123 scraped, 20 new items
# [Worker 2] Page 125 scraped, 20 new items
# [Worker 5] Page 124 scraped, 20 new items
# [Worker 4] Page 126 scraped, 20 new items
# [Worker 6] Page 127 scraped, 20 new items
# [Worker 3] Page 129 scraped, 20 new items
# [Worker 7] Page 128 scraped, 20 new items
# [Worker 1] Page 130 scraped, 20 new items
# [Worker 5] Page 132 scraped, 20 new items
# [Worker 2] Page 131 scraped, 20 new items
# [Worker 4] Page 133 scraped, 20 new items
# [Worker 6] Page 134 scraped, 20 new items
# [Worker 3] Page 135 scraped, 20 new items
# [Worker 7] Page 136 scraped, 19 new items
# [Worker 1] Page 137 scraped, 20 new items
# [Worker 5] Page 138 scraped, 20 new items
# [Worker 2] Page 139 scraped, 20 new items
# [Worker 4] Page 140 scraped, 20 new items
# [Worker 3] Page 142 scraped, 20 new items
# [Worker 7] Page 143 scraped, 20 new items
# [Worker 6] Page 141 scraped, 20 new items
# [Worker 1] Page 144 scraped, 20 new items
# [Worker 5] Page 145 scraped, 20 new items
# [Worker 2] Page 146 scraped, 20 new items
# [Worker 4] Page 147 scraped, 20 new items
# [Worker 3] Page 148 scraped, 20 new items
# [Worker 6] Page 150 scraped, 20 new items
# [Worker 7] Page 149 scraped, 20 new items
# [Worker 1] Page 151 scraped, 20 new items
# [Worker 5] Page 152 scraped, 20 new items
# [Worker 2] Page 153 scraped, 20 new items
# [Worker 4] Page 154 scraped, 20 new items
# [Worker 7] Page 157 scraped, 20 new items
# [Worker 3] Page 155 scraped, 20 new items
# [Worker 6] Page 156 scraped, 19 new items
# [Worker 1] Page 158 scraped, 20 new items
# [Worker 2] Page 160 scraped, 20 new items
# [Worker 5] Page 159 scraped, 20 new items
# [Worker 4] Page 161 scraped, 19 new items
# [Worker 1] Page 165 scraped, 20 new items
# [Worker 6] Page 164 scraped, 20 new items
# [Worker 3] Page 163 scraped, 20 new items
# [Worker 7] Page 162 scraped, 20 new items
# [Worker 5] Page 167 scraped, 20 new items
# [Worker 2] Page 166 scraped, 20 new items
# [Worker 4] Page 168 scraped, 20 new items
# [Worker 3] Page 171 scraped, 20 new items
# [Worker 6] Page 170 scraped, 20 new items
# [Worker 7] Page 172 scraped, 20 new items
# [Worker 1] Page 169 scraped, 20 new items
# [Worker 5] Page 173 scraped, 20 new items
# [Worker 2] Page 174 scraped, 20 new items
# [Worker 4] Page 175 scraped, 20 new items
# [Worker 6] Page 177 scraped, 20 new items
# [Worker 7] Page 178 scraped, 20 new items
# [Worker 1] Page 179 scraped, 20 new items
# [Worker 3] Page 176 scraped, 20 new items
# [Worker 2] Page 181 scraped, 20 new items
# [Worker 5] Page 180 scraped, 20 new items
# [Worker 4] Page 182 scraped, 20 new items
# [Worker 6] Page 183 scraped, 20 new items
# [Worker 3] Page 186 scraped, 20 new items
# [Worker 1] Page 185 scraped, 20 new items
# [Worker 7] Page 184 scraped, 20 new items
# [Worker 2] Page 187 scraped, 20 new items
# [Worker 5] Page 188 scraped, 20 new items
# [Worker 4] Page 189 scraped, 20 new items
# [Worker 7] Page 193 scraped, 20 new items
# [Worker 6] Page 190 scraped, 20 new items
# [Worker 3] Page 191 scraped, 20 new items
# [Worker 1] Page 192 scraped, 20 new items
# [Worker 5] Page 195 scraped, 20 new items
# [Worker 2] Page 194 scraped, 20 new items
# [Worker 4] Page 196 scraped, 20 new items
# [Worker 3] Page 199 scraped, 20 new items
# [Worker 7] Page 197 scraped, 20 new items
# [Worker 1] Page 200 scraped, 20 new items
# [Worker 6] Page 198 scraped, 20 new items
# [Worker 5] Page 201 scraped, 20 new items
# [Worker 2] Page 202 scraped, 20 new items
# [Worker 4] Page 203 scraped, 20 new items
# [Worker 7] Page 205 scraped, 20 new items
# [Worker 3] Page 204 scraped, 20 new items
# [Worker 1] Page 206 scraped, 20 new items
# [Worker 6] Page 207 scraped, 20 new items
# [Worker 5] Page 208 scraped, 20 new items
# [Worker 2] Page 209 scraped, 20 new items
# [Worker 4] Page 210 scraped, 20 new items
# [Worker 7] Page 211 scraped, 20 new items
# [Worker 3] Page 212 scraped, 20 new items
# [Worker 1] Page 213 scraped, 20 new items
# [Worker 6] Page 214 scraped, 20 new items
# [Worker 2] Page 216 scraped, 20 new items
# [Worker 5] Page 215 scraped, 20 new items
# [Worker 4] Page 217 scraped, 20 new items
# [Worker 3] Page 219 scraped, 20 new items
# [Worker 1] Page 220 scraped, 20 new items
# [Worker 7] Page 218 scraped, 20 new items
# [Worker 6] Page 221 scraped, 20 new items
# [Worker 5] Page 223 scraped, 20 new items
# [Worker 2] Page 222 scraped, 20 new items
# [Worker 4] Page 224 scraped, 20 new items
# [Worker 1] Page 226 scraped, 20 new items
# [Worker 3] Page 225 scraped, 20 new items
# [Worker 7] Page 227 scraped, 20 new items
# [Worker 6] Page 228 scraped, 20 new items
# [Worker 5] Page 229 scraped, 20 new items
# [Worker 2] Page 230 scraped, 20 new items
# [Worker 4] Page 231 scraped, 20 new items
# [Worker 1] Page 232 scraped, 20 new items
# [Worker 7] Page 234 scraped, 20 new items
# [Worker 3] Page 233 scraped, 20 new items
# [Worker 6] Page 235 scraped, 20 new items
# [Worker 5] Page 236 scraped, 20 new items
# [Worker 2] Page 237 scraped, 20 new items
# [Worker 4] Page 238 scraped, 20 new items
# [Worker 7] Page 240 scraped, 20 new items
# [Worker 3] Page 241 scraped, 20 new items
# [Worker 1] Page 239 scraped, 19 new items
# [Worker 6] Page 242 scraped, 20 new items
# [Worker 2] Page 244 scraped, 20 new items[Worker 5] Page 243 scraped, 20 new items
#
# [Worker 3] Page 247 scraped, 20 new items
# [Worker 4] Page 245 scraped, 20 new items
# [Worker 7] Page 246 scraped, 20 new items
# [Worker 1] Page 248 scraped, 20 new items
# [Worker 6] Page 249 scraped, 20 new items
# [Worker 2] Page 251 scraped, 20 new items[Worker 5] Page 250 scraped, 20 new items
#
# [Worker 4] Page 253 scraped, 20 new items
# [Worker 1] Page 255 scraped, 20 new items
# [Worker 7] Page 254 scraped, 20 new items
# [Worker 3] Page 252 scraped, 20 new items
# [Worker 6] Page 256 scraped, 20 new items
# [Worker 2] Page 258 scraped, 20 new items
# [Worker 5] Page 257 scraped, 19 new items
# [Worker 1] Page 260 scraped, 20 new items
# [Worker 7] Page 261 scraped, 20 new items
# [Worker 4] Page 259 scraped, 20 new items
# [Worker 3] Page 262 scraped, 20 new items
# [Worker 6] Page 263 scraped, 20 new items
# [Worker 5] Page 265 scraped, 20 new items
# [Worker 2] Page 264 scraped, 20 new items
# [Worker 1] Page 266 scraped, 20 new items
# [Worker 4] Page 268 scraped, 20 new items
# [Worker 7] Page 267 scraped, 20 new items
# [Worker 3] Page 269 scraped, 20 new items
# [Worker 6] Page 270 scraped, 20 new items
# [Worker 2] Page 272 scraped, 20 new items
# [Worker 5] Page 271 scraped, 20 new items
# [Worker 7] Page 275 scraped, 20 new items[Worker 4] Page 274 scraped, 19 new items
#
# [Worker 1] Page 273 scraped, 20 new items
# [Worker 6] Page 277 scraped, 20 new items
# [Worker 5] Page 279 scraped, 20 new items
# [Worker 2] Page 278 scraped, 20 new items
# [Worker 3] Page 276 scraped, 20 new items
# [Worker 1] Page 282 scraped, 20 new items
# [Worker 4] Page 281 scraped, 20 new items
# [Worker 7] Page 280 scraped, 20 new items
# [Worker 6] Page 283 scraped, 20 new items
# [Worker 2] Page 285 scraped, 20 new items
# [Worker 5] Page 284 scraped, 19 new items
# [Worker 3] Page 286 scraped, 20 new items
# [Worker 4] Page 288 scraped, 20 new items
# [Worker 1] Page 287 scraped, 20 new items
# [Worker 7] Page 289 scraped, 20 new items
# [Worker 6] Page 290 scraped, 20 new items
# [Worker 5] Page 292 scraped, 20 new items
# [Worker 2] Page 291 scraped, 20 new items
# [Worker 3] Page 293 scraped, 20 new items
# [Worker 7] Page 296 scraped, 20 new items
# [Worker 1] Page 295 scraped, 20 new items
# [Worker 4] Page 294 scraped, 20 new items
# [Worker 6] Page 297 scraped, 20 new items
# [Worker 5] Page 298 scraped, 20 new items
# [Worker 2] Page 299 scraped, 20 new items
# [Worker 3] Page 300 scraped, 20 new items
# [Worker 7] Page 301 scraped, 20 new items
# [Worker 4] Page 303 scraped, 20 new items
# [Worker 1] Page 302 scraped, 20 new items
# [Worker 6] Page 304 scraped, 20 new items
# [Worker 5] Page 305 scraped, 20 new items
# [Worker 3] Page 307 scraped, 20 new items
# [Worker 2] Page 306 scraped, 20 new items
# [Worker 7] Page 308 scraped, 20 new items
# [Worker 4] Page 309 scraped, 20 new items
# [Worker 1] Page 310 scraped, 20 new items
# [Worker 6] Page 311 scraped, 20 new items
# [Worker 5] Page 312 scraped, 20 new items
# [Worker 3] Page 313 scraped, 20 new items
# [Worker 2] Page 314 scraped, 20 new items
# [Worker 6] Page 318 scraped, 20 new items
# [Worker 7] Page 315 scraped, 20 new items
# [Worker 4] Page 316 scraped, 20 new items
# [Worker 1] Page 317 scraped, 20 new items
# [Worker 5] Page 319 scraped, 20 new items
# [Worker 3] Page 320 scraped, 20 new items
# [Worker 2] Page 321 scraped, 20 new items
# [Worker 4] Page 324 scraped, 20 new items
# [Worker 7] Page 323 scraped, 20 new items
# [Worker 1] Page 325 scraped, 20 new items
# [Worker 6] Page 322 scraped, 20 new items
# [Worker 5] Page 326 scraped, 20 new items
# [Worker 3] Page 327 scraped, 20 new items
# [Worker 2] Page 328 scraped, 20 new items
# [Worker 4] Page 329 scraped, 20 new items
# [Worker 6] Page 332 scraped, 20 new items
# [Worker 1] Page 331 scraped, 20 new items
# [Worker 7] Page 330 scraped, 20 new items
# [Worker 5] Page 333 scraped, 20 new items
# [Worker 3] Page 334 scraped, 20 new items
# [Worker 2] Page 335 scraped, 20 new items
# [Worker 4] Page 336 scraped, 20 new items
# [Worker 1] Page 338 scraped, 20 new items
# [Worker 6] Page 337 scraped, 20 new items
# [Worker 7] Page 339 scraped, 20 new items
# [Worker 5] Page 340 scraped, 20 new items
# [Worker 3] Page 341 scraped, 20 new items
# [Worker 2] Page 342 scraped, 20 new items
# [Worker 1] Page 344 scraped, 20 new items
# [Worker 6] Page 345 scraped, 20 new items
# [Worker 4] Page 343 scraped, 20 new items
# [Worker 7] Page 346 scraped, 20 new items
# [Worker 5] Page 347 scraped, 20 new items
# [Worker 3] Page 348 scraped, 20 new items
# [Worker 2] Page 349 scraped, 20 new items
# [Worker 4] Page 352 scraped, 20 new items
# [Worker 6] Page 351 scraped, 20 new items
# [Worker 1] Page 350 scraped, 20 new items
# [Worker 7] Page 353 scraped, 20 new items
# [Worker 5] Page 354 scraped, 20 new items
# [Worker 3] Page 355 scraped, 20 new items
# [Worker 2] Page 356 scraped, 20 new items
# [Worker 6] Page 358 scraped, 20 new items
# [Worker 4] Page 357 scraped, 20 new items
# [Worker 1] Page 359 scraped, 20 new items
# [Worker 7] Page 360 scraped, 20 new items
# [Worker 5] Page 361 scraped, 20 new items
# [Worker 3] Page 362 scraped, 20 new items
# [Worker 2] Page 363 scraped, 20 new items
# [Worker 1] Page 366 scraped, 20 new items
# [Worker 6] Page 364 scraped, 20 new items
# [Worker 7] Page 367 scraped, 20 new items
# [Worker 4] Page 365 scraped, 20 new items
# [Worker 5] Page 368 scraped, 20 new items
# [Worker 3] Page 369 scraped, 20 new items
# [Worker 2] Page 370 scraped, 20 new items
# [Worker 1] Page 371 scraped, 11 new items
# [Worker 4] Page 374 scraped, 20 new items
# [Worker 6] Page 372 scraped, 20 new items
# [Worker 7] Page 373 scraped, 12 new items
# [Worker 5] Page 375 scraped, 20 new items
# [Worker 3] Page 376 scraped, 20 new items
# [Worker 2] Page 377 scraped, 11 new items
# [Worker 1] Page 378 scraped, 20 new items[Worker 6] Page 380 scraped, 20 new items
#
# [Worker 4] Page 379 scraped, 12 new items
# [Worker 5] Page 382 scraped, 20 new items
# [Worker 7] Page 381 scraped, 14 new items
# [Worker 3] Page 383 scraped, 16 new items
# [Worker 2] Page 384 scraped, 20 new items
# [Worker 4] Page 387 scraped, 20 new items
# [Worker 5] Page 388 scraped, 20 new items
# [Worker 1] Page 386 scraped, 13 new items
# [Worker 7] Page 389 scraped, 20 new items
# [Worker 6] Page 385 scraped, 16 new items
# [Worker 3] Page 390 scraped, 13 new items
# [Worker 2] Page 391 scraped, 20 new items
# [Worker 6] Page 396 scraped, 20 new items
# [Worker 5] Page 393 scraped, 20 new items
# [Worker 4] Page 392 scraped, 16 new items
# [Worker 7] Page 395 scraped, 12 new items
# [Worker 1] Page 394 scraped, 10 new items
# [Worker 3] Page 397 scraped, 20 new items
# [Worker 2] Page 398 scraped, 11 new items
# [Worker 1] Page 403 scraped, 20 new items
# [Worker 3] Page 404 scraped, 20 new items
# [Worker 5] Page 400 scraped, 20 new items
# [Worker 4] Page 401 scraped, 20 new items
# [Worker 7] Page 402 scraped, 20 new items
# [Worker 6] Page 399 scraped, 20 new items
# [Worker 2] Page 405 scraped, 20 new items
# [Worker 1] Page 406 scraped, 20 new items
# [Worker 6] Page 410 scraped, 20 new items
# [Worker 4] Page 409 scraped, 20 new items
# [Worker 7] Page 411 scraped, 20 new items
# [Worker 3] Page 407 scraped, 20 new items
# [Worker 5] Page 408 scraped, 20 new items
# [Worker 2] Page 412 scraped, 20 new items
# [Worker 6] Page 414 scraped, 20 new items[Worker 1] Page 413 scraped, 19 new items
#
# [Worker 3] Page 417 scraped, 20 new items
# [Worker 5] Page 418 scraped, 20 new items
# [Worker 4] Page 415 scraped, 20 new items
# [Worker 7] Page 416 scraped, 20 new items
# [Worker 2] Page 419 scraped, 20 new items
# [Worker 6] Page 420 scraped, 20 new items
# [Worker 1] Page 421 scraped, 20 new items
# [Worker 3] Page 422 scraped, 20 new items
# [Worker 4] Page 424 scraped, 20 new items
# [Worker 5] Page 423 scraped, 20 new items
# [Worker 7] Page 425 scraped, 20 new items
# [Worker 2] Page 426 scraped, 20 new items
# [Worker 4] Page 430 scraped, 20 new items[Worker 1] Page 428 scraped, 20 new items
#
# [Worker 6] Page 427 scraped, 20 new items
# [Worker 3] Page 429 scraped, 20 new items
# [Worker 5] Page 431 scraped, 20 new items
# [Worker 7] Page 432 scraped, 20 new items
# [Worker 2] Page 433 scraped, 20 new items
# [Worker 3] Page 437 scraped, 20 new items
# [Worker 4] Page 435 scraped, 20 new items
# [Worker 5] Page 438 scraped, 19 new items
# [Worker 1] Page 434 scraped, 19 new items
# [Worker 6] Page 436 scraped, 20 new items
# [Worker 7] Page 439 scraped, 20 new items
# [Worker 2] Page 440 scraped, 20 new items
# [Worker 6] Page 445 scraped, 20 new items
# [Worker 1] Page 444 scraped, 20 new items
# [Worker 3] Page 441 scraped, 20 new items
# [Worker 5] Page 443 scraped, 20 new items
# [Worker 4] Page 442 scraped, 20 new items
# [Worker 7] Page 446 scraped, 20 new items
# [Worker 2] Page 447 scraped, 20 new items
# [Worker 3] Page 450 scraped, 20 new items
# [Worker 1] Page 449 scraped, 20 new items
# [Worker 5] Page 451 scraped, 20 new items
# [Worker 6] Page 448 scraped, 20 new items
# [Worker 4] Page 452 scraped, 20 new items
# [Worker 7] Page 453 scraped, 19 new items
# [Worker 2] Page 454 scraped, 20 new items
# [Worker 6] Page 458 scraped, 20 new items
# [Worker 1] Page 456 scraped, 20 new items
# [Worker 4] Page 459 scraped, 20 new items
# [Worker 5] Page 457 scraped, 20 new items
# [Worker 3] Page 455 scraped, 20 new items
# [Worker 7] Page 460 scraped, 20 new items
# [Worker 2] Page 461 scraped, 20 new items
# [Worker 5] Page 465 scraped, 20 new items
# [Worker 1] Page 463 scraped, 20 new items
# [Worker 6] Page 462 scraped, 20 new items
# [Worker 3] Page 466 scraped, 20 new items
# [Worker 4] Page 464 scraped, 20 new items
# [Worker 7] Page 467 scraped, 20 new items
# [Worker 2] Page 468 scraped, 20 new items
# [Worker 5] Page 469 scraped, 20 new items
# [Worker 3] Page 472 scraped, 20 new items
# [Worker 6] Page 471 scraped, 19 new items
# [Worker 1] Page 470 scraped, 20 new items
# [Worker 4] Page 473 scraped, 20 new items
# [Worker 7] Page 474 scraped, 20 new items
# [Worker 2] Page 475 scraped, 20 new items
# [Worker 5] Page 476 scraped, 20 new items
# [Worker 3] Page 477 scraped, 20 new items
# [Worker 4] Page 480 scraped, 20 new items
# [Worker 7] Page 481 scraped, 20 new items
# [Worker 6] Page 478 scraped, 20 new items
# [Worker 1] Page 479 scraped, 20 new items
# [Worker 2] Page 482 scraped, 20 new items
# [Worker 5] Page 483 scraped, 20 new items
# [Worker 7] Page 486 scraped, 20 new items
# [Worker 6] Page 487 scraped, 20 new items
# [Worker 3] Page 484 scraped, 20 new items
# [Worker 4] Page 485 scraped, 20 new items
# [Worker 1] Page 488 scraped, 20 new items
# [Worker 2] Page 489 scraped, 20 new items
# [Worker 5] Page 490 scraped, 20 new items
# [Worker 7] Page 491 scraped, 20 new items
# [Worker 3] Page 493 scraped, 20 new items
# [Worker 4] Page 494 scraped, 20 new items
# [Worker 6] Page 492 scraped, 20 new items
# [Worker 1] Page 495 scraped, 20 new items
# [Worker 2] Page 496 scraped, 20 new items
# [Worker 5] Page 497 scraped, 20 new items
# [Worker 3] Page 499 scraped, 20 new items
# [Worker 7] Page 498 scraped, 20 new items
# [Worker 6] Page 501 scraped, 20 new items
# [Worker 4] Page 500 scraped, 20 new items
# [Worker 1] Page 502 scraped, 20 new items
# [Worker 2] Page 503 scraped, 20 new items
# [Worker 5] Page 504 scraped, 20 new items
# [Worker 7] Page 506 scraped, 20 new items
# [Worker 6] Page 507 scraped, 20 new items
# [Worker 3] Page 505 scraped, 20 new items
# [Worker 1] Page 509 scraped, 20 new items
# [Worker 4] Page 508 scraped, 20 new items
# [Worker 2] Page 510 scraped, 20 new items
# [Worker 5] Page 511 scraped, 19 new items
# [Worker 7] Page 512 scraped, 20 new items
# [Worker 6] Page 513 scraped, 20 new items
# [Worker 3] Page 514 scraped, 20 new items
# [Worker 2] Page 517 scraped, 20 new items
# [Worker 4] Page 516 scraped, 20 new items
# [Worker 1] Page 515 scraped, 20 new items
# [Worker 5] Page 518 scraped, 20 new items
# [Worker 7] Page 519 scraped, 20 new items
# [Worker 3] Page 521 scraped, 20 new items
# [Worker 6] Page 520 scraped, 20 new items
# [Worker 2] Page 522 scraped, 20 new items
# [Worker 4] Page 523 scraped, 20 new items
# [Worker 1] Page 524 scraped, 20 new items
# [Worker 5] Page 525 scraped, 20 new items
# [Worker 6] Page 528 scraped, 20 new items
# [Worker 7] Page 526 scraped, 20 new items
# [Worker 3] Page 527 scraped, 20 new items
# [Worker 2] Page 529 scraped, 20 new items
# [Worker 4] Page 530 scraped, 20 new items
# [Worker 1] Page 531 scraped, 20 new items
# [Worker 5] Page 532 scraped, 20 new items
# [Worker 6] Page 533 scraped, 20 new items
# [Worker 7] Page 534 scraped, 20 new items
# [Worker 3] Page 535 scraped, 20 new items
# [Worker 2] Page 536 scraped, 20 new items
# [Worker 1] Page 538 scraped, 20 new items
# [Worker 4] Page 537 scraped, 20 new items
# [Worker 5] Page 539 scraped, 20 new items
# [Worker 3] Page 542 scraped, 20 new items[Worker 7] Page 541 scraped, 20 new items
#
# [Worker 6] Page 540 scraped, 20 new items
# [Worker 2] Page 543 scraped, 20 new items
# [Worker 4] Page 545 scraped, 20 new items
# [Worker 1] Page 544 scraped, 20 new items
# [Worker 5] Page 546 scraped, 20 new items
# [Worker 7] Page 548 scraped, 20 new items
# [Worker 3] Page 547 scraped, 20 new items
# [Worker 6] Page 549 scraped, 19 new items
# [Worker 2] Page 550 scraped, 20 new items
# [Worker 1] Page 552 scraped, 20 new items
# [Worker 4] Page 551 scraped, 20 new items
# [Worker 5] Page 553 scraped, 20 new items
# [Worker 6] Page 556 scraped, 20 new items
# [Worker 7] Page 554 scraped, 20 new items
# [Worker 3] Page 555 scraped, 20 new items
# [Worker 2] Page 557 scraped, 20 new items
# [Worker 1] Page 558 scraped, 20 new items
# [Worker 4] Page 559 scraped, 20 new items
# [Worker 5] Page 560 scraped, 20 new items
# [Worker 6] Page 561 scraped, 20 new items
# [Worker 7] Page 562 scraped, 20 new items
# [Worker 3] Page 563 scraped, 20 new items
# [Worker 2] Page 564 scraped, 20 new items
# [Worker 1] Page 565 scraped, 20 new items
# [Worker 4] Page 566 scraped, 20 new items
# [Worker 5] Page 567 scraped, 20 new items
# [Worker 7] Page 569 scraped, 20 new items[Worker 3] Page 570 scraped, 20 new items
#
# [Worker 6] Page 568 scraped, 20 new items
# [Worker 2] Page 571 scraped, 19 new items
# [Worker 4] Page 573 scraped, 20 new items
# [Worker 1] Page 572 scraped, 20 new items
# [Worker 5] Page 574 scraped, 20 new items
# [Worker 7] Page 576 scraped, 20 new items
# [Worker 6] Page 577 scraped, 20 new items
# [Worker 3] Page 575 scraped, 20 new items
# [Worker 2] Page 578 scraped, 20 new items
# [Worker 1] Page 580 scraped, 20 new items
# [Worker 4] Page 579 scraped, 20 new items
# [Worker 5] Page 581 scraped, 20 new items
# [Worker 7] Page 582 scraped, 20 new items
# [Worker 6] Page 583 scraped, 20 new items
# [Worker 3] Page 584 scraped, 20 new items
# [Worker 2] Page 585 scraped, 20 new items
# [Worker 4] Page 587 scraped, 20 new items
# [Worker 1] Page 586 scraped, 20 new items
# [Worker 5] Page 588 scraped, 20 new items
# [Worker 3] Page 591 scraped, 20 new items
# [Worker 6] Page 590 scraped, 20 new items
# [Worker 7] Page 589 scraped, 20 new items
# [Worker 2] Page 592 scraped, 20 new items
# [Worker 4] Page 593 scraped, 20 new items
# [Worker 1] Page 594 scraped, 19 new items
# [Worker 5] Page 595 scraped, 20 new items
# [Worker 3] Page 596 scraped, 20 new items
# [Worker 6] Page 597 scraped, 20 new items
# [Worker 7] Page 598 scraped, 20 new items
# [Worker 2] Page 599 scraped, 20 new items
# [Worker 4] Page 600 scraped, 20 new items
# [Worker 1] Page 601 scraped, 20 new items
# [Worker 5] Page 602 scraped, 20 new items
# [Worker 6] Page 604 scraped, 20 new items
# [Worker 3] Page 603 scraped, 20 new items
# [Worker 7] Page 605 scraped, 20 new items
# [Worker 2] Page 606 scraped, 20 new items
# [Worker 4] Page 607 scraped, 20 new items
# [Worker 1] Page 608 scraped, 20 new items
# [Worker 5] Page 609 scraped, 19 new items
# [Worker 7] Page 612 scraped, 20 new items
# [Worker 3] Page 611 scraped, 20 new items
# [Worker 6] Page 610 scraped, 20 new items
# [Worker 2] Page 613 scraped, 20 new items
# [Worker 4] Page 614 scraped, 20 new items
# [Worker 1] Page 615 scraped, 20 new items
# [Worker 5] Page 616 scraped, 20 new items
# [Worker 3] Page 618 scraped, 20 new items[Worker 7] Page 617 scraped, 20 new items
#
# [Worker 6] Page 619 scraped, 20 new items
# [Worker 2] Page 620 scraped, 20 new items
# [Worker 4] Page 621 scraped, 20 new items
# [Worker 1] Page 622 scraped, 20 new items
# [Worker 5] Page 623 scraped, 20 new items
# [Worker 6] Page 626 scraped, 20 new items
# [Worker 7] Page 625 scraped, 20 new items
# [Worker 3] Page 624 scraped, 20 new items
# [Worker 2] Page 627 scraped, 20 new items
# [Worker 4] Page 628 scraped, 20 new items
# [Worker 1] Page 629 scraped, 20 new items
# [Worker 5] Page 630 scraped, 20 new items
# [Worker 6] Page 631 scraped, 20 new items
# [Worker 3] Page 633 scraped, 20 new items
# [Worker 7] Page 632 scraped, 20 new items
# [Worker 4] Page 635 scraped, 20 new items
# [Worker 2] Page 634 scraped, 20 new items
# [Worker 1] Page 636 scraped, 20 new items
# [Worker 5] Page 637 scraped, 20 new items
# [Worker 6] Page 638 scraped, 20 new items
# [Worker 3] Page 639 scraped, 20 new items
# [Worker 7] Page 640 scraped, 20 new items
# [Worker 2] Page 642 scraped, 20 new items
# [Worker 4] Page 641 scraped, 19 new items
# [Worker 1] Page 643 scraped, 20 new items
# [Worker 5] Page 644 scraped, 19 new items
# [Worker 6] Page 645 scraped, 20 new items
# [Worker 3] Page 646 scraped, 20 new items
# [Worker 7] Page 647 scraped, 20 new items
# [Worker 2] Page 648 scraped, 20 new items
# [Worker 4] Page 649 scraped, 20 new items
# [Worker 1] Page 650 scraped, 20 new items
# [Worker 5] Page 651 scraped, 20 new items
# [Worker 3] Page 653 scraped, 20 new items
# [Worker 7] Page 654 scraped, 19 new items
# [Worker 6] Page 652 scraped, 20 new items
# [Worker 2] Page 655 scraped, 20 new items
# [Worker 4] Page 656 scraped, 20 new items
# [Worker 1] Page 657 scraped, 20 new items
# [Worker 5] Page 658 scraped, 20 new items
# [Worker 6] Page 661 scraped, 20 new items
# [Worker 7] Page 660 scraped, 20 new items
# [Worker 3] Page 659 scraped, 20 new items
# [Worker 2] Page 662 scraped, 20 new items
# [Worker 4] Page 663 scraped, 20 new items
# [Worker 1] Page 664 scraped, 20 new items
# [Worker 5] Page 665 scraped, 20 new items
# [Worker 6] Page 666 scraped, 20 new items
# [Worker 3] Page 668 scraped, 20 new items
# [Worker 7] Page 667 scraped, 20 new items
# [Worker 4] Page 670 scraped, 20 new items
# [Worker 2] Page 669 scraped, 20 new items
# [Worker 1] Page 671 scraped, 20 new items
# [Worker 5] Page 672 scraped, 20 new items
# [Worker 7] Page 675 scraped, 20 new items
# [Worker 6] Page 673 scraped, 20 new items
# [Worker 3] Page 674 scraped, 20 new items
# [Worker 4] Page 676 scraped, 20 new items
# [Worker 2] Page 677 scraped, 20 new items
# [Worker 1] Page 678 scraped, 20 new items
# [Worker 5] Page 679 scraped, 20 new items
# [Worker 3] Page 682 scraped, 20 new items
# [Worker 6] Page 681 scraped, 19 new items
# [Worker 7] Page 680 scraped, 20 new items
# [Worker 2] Page 684 scraped, 20 new items
# [Worker 4] Page 683 scraped, 18 new items
# [Worker 1] Page 685 scraped, 20 new items
# [Worker 5] Page 686 scraped, 20 new items
# [Worker 3] Page 687 scraped, 20 new items
# [Worker 6] Page 688 scraped, 20 new items
# [Worker 7] Page 689 scraped, 20 new items
# [Worker 4] Page 691 scraped, 20 new items
# [Worker 2] Page 690 scraped, 20 new items
# [Worker 1] Page 692 scraped, 20 new items
# [Worker 5] Page 693 scraped, 19 new items
# [Worker 6] Page 695 scraped, 20 new items
# [Worker 3] Page 694 scraped, 20 new items
# [Worker 7] Page 696 scraped, 20 new items
# [Worker 2] Page 698 scraped, 20 new items
# [Worker 4] Page 697 scraped, 20 new items
# [Worker 1] Page 699 scraped, 20 new items
# [Worker 3] Page 702 scraped, 20 new items
# [Worker 5] Page 700 scraped, 19 new items
# [Worker 7] Page 703 scraped, 20 new items
# [Worker 6] Page 701 scraped, 20 new items
# [Worker 4] Page 705 scraped, 20 new items
# [Worker 2] Page 704 scraped, 20 new items
# [Worker 1] Page 706 scraped, 20 new items
# [Worker 6] Page 710 scraped, 20 new items
# [Worker 3] Page 707 scraped, 20 new items
# [Worker 7] Page 709 scraped, 20 new items
# [Worker 5] Page 708 scraped, 20 new items
# [Worker 2] Page 712 scraped, 20 new items
# [Worker 4] Page 711 scraped, 20 new items
# [Worker 1] Page 713 scraped, 20 new items
# [Worker 7] Page 716 scraped, 20 new items
# [Worker 5] Page 717 scraped, 20 new items
# [Worker 3] Page 715 scraped, 20 new items
# [Worker 6] Page 714 scraped, 20 new items
# [Worker 2] Page 718 scraped, 20 new items
# [Worker 4] Page 719 scraped, 20 new items
# [Worker 1] Page 720 scraped, 20 new items
# [Worker 5] Page 722 scraped, 20 new items
# [Worker 7] Page 721 scraped, 20 new items
# [Worker 3] Page 723 scraped, 20 new items
# [Worker 6] Page 724 scraped, 20 new items
# [Worker 2] Page 725 scraped, 20 new items
# [Worker 4] Page 726 scraped, 20 new items
# [Worker 1] Page 727 scraped, 20 new items
# [Worker 6] Page 731 scraped, 20 new items
# [Worker 5] Page 728 scraped, 20 new items
# [Worker 7] Page 729 scraped, 20 new items
# [Worker 3] Page 730 scraped, 20 new items
# [Worker 4] Page 733 scraped, 20 new items
# [Worker 2] Page 732 scraped, 19 new items
# [Worker 1] Page 734 scraped, 20 new items
# [Worker 6] Page 735 scraped, 20 new items
# [Worker 3] Page 738 scraped, 20 new items
# [Worker 7] Page 737 scraped, 20 new items
# [Worker 5] Page 736 scraped, 20 new items
# [Worker 4] Page 739 scraped, 20 new items
# [Worker 2] Page 740 scraped, 20 new items
# [Worker 1] Page 741 scraped, 20 new items
# [Worker 5] Page 745 scraped, 20 new items
# [Worker 3] Page 743 scraped, 20 new items
# [Worker 7] Page 744 scraped, 20 new items
# [Worker 6] Page 742 scraped, 20 new items
# [Worker 2] Page 747 scraped, 20 new items
# [Worker 4] Page 746 scraped, 20 new items
# [Worker 1] Page 748 scraped, 20 new items
# [Worker 3] Page 750 scraped, 20 new items[Worker 6] Page 752 scraped, 20 new items
#
# [Worker 5] Page 749 scraped, 20 new items
# [Worker 7] Page 751 scraped, 20 new items
# [Worker 4] Page 754 scraped, 20 new items
# [Worker 2] Page 753 scraped, 20 new items
# [Worker 1] Page 755 scraped, 20 new items
# [Worker 5] Page 758 scraped, 20 new items
# [Worker 7] Page 759 scraped, 20 new items
# [Worker 3] Page 757 scraped, 20 new items
# [Worker 6] Page 756 scraped, 20 new items
# [Worker 2] Page 761 scraped, 20 new items
# [Worker 4] Page 760 scraped, 20 new items
# [Worker 1] Page 762 scraped, 20 new items
# [Worker 7] Page 764 scraped, 20 new items
# [Worker 5] Page 763 scraped, 20 new items
# [Worker 6] Page 766 scraped, 20 new items
# [Worker 3] Page 765 scraped, 20 new items
# [Worker 4] Page 768 scraped, 20 new items[Worker 2] Page 767 scraped, 20 new items
#
# [Worker 1] Page 769 scraped, 20 new items
# [Worker 3] Page 773 scraped, 20 new items
# [Worker 7] Page 770 scraped, 20 new items
# [Worker 6] Page 772 scraped, 20 new items
# [Worker 5] Page 771 scraped, 20 new items
# [Worker 2] Page 774 scraped, 20 new items
# [Worker 4] Page 775 scraped, 20 new items
# [Worker 1] Page 776 scraped, 20 new items
# [Worker 3] Page 777 scraped, 20 new items
# [Worker 6] Page 779 scraped, 20 new items
# [Worker 7] Page 778 scraped, 20 new items
# [Worker 5] Page 780 scraped, 20 new items
# [Worker 2] Page 781 scraped, 20 new items
# [Worker 4] Page 782 scraped, 20 new items
# [Worker 1] Page 783 scraped, 20 new items
# [Worker 3] Page 784 scraped, 20 new items
# [Worker 6] Page 785 scraped, 20 new items
# [Worker 5] Page 787 scraped, 20 new items
# [Worker 7] Page 786 scraped, 20 new items
# [Worker 4] Page 789 scraped, 20 new items
# [Worker 2] Page 788 scraped, 20 new items
# [Worker 1] Page 790 scraped, 20 new items
# [Worker 3] Page 791 scraped, 20 new items
# [Worker 5] Page 793 scraped, 20 new items
# [Worker 6] Page 792 scraped, 20 new items
# [Worker 7] Page 794 scraped, 20 new items
# [Worker 2] Page 796 scraped, 20 new items
# [Worker 4] Page 795 scraped, 20 new items
# [Worker 1] Page 797 scraped, 20 new items
# [Worker 6] Page 800 scraped, 20 new items
# [Worker 5] Page 799 scraped, 20 new items
# [Worker 3] Page 798 scraped, 20 new items
# [Worker 7] Page 801 scraped, 20 new items
# [Worker 4] Page 803 scraped, 20 new items
# [Worker 2] Page 802 scraped, 20 new items
# [Worker 1] Page 804 scraped, 20 new items
# [Worker 5] Page 806 scraped, 20 new items
# [Worker 6] Page 805 scraped, 20 new items
# [Worker 3] Page 807 scraped, 20 new items
# [Worker 7] Page 808 scraped, 20 new items
# [Worker 4] Page 809 scraped, 20 new items
# [Worker 2] Page 810 scraped, 20 new items
# [Worker 1] Page 811 scraped, 20 new items
# [Worker 5] Page 812 scraped, 20 new items
# [Worker 3] Page 814 scraped, 20 new items
# [Worker 7] Page 815 scraped, 20 new items
# [Worker 6] Page 813 scraped, 20 new items
# [Worker 4] Page 816 scraped, 20 new items
# [Worker 2] Page 817 scraped, 20 new items
# [Worker 1] Page 818 scraped, 20 new items
# [Worker 5] Page 819 scraped, 20 new items
# [Worker 6] Page 822 scraped, 20 new items
# [Worker 4] Page 823 scraped, 20 new items
# [Worker 3] Page 820 scraped, 20 new items
# [Worker 2] Page 824 scraped, 20 new items
# [Worker 7] Page 821 scraped, 20 new items
# [Worker 1] Page 825 scraped, 20 new items
# [Worker 5] Page 826 scraped, 20 new items
# [Worker 7] Page 831 scraped, 20 new items
# [Worker 6] Page 827 scraped, 20 new items
# [Worker 3] Page 829 scraped, 20 new items
# [Worker 2] Page 830 scraped, 20 new items
# [Worker 4] Page 828 scraped, 20 new items
# [Worker 1] Page 832 scraped, 20 new items
# [Worker 5] Page 833 scraped, 20 new items
# [Worker 7] Page 834 scraped, 20 new items[Worker 4] Page 838 scraped, 20 new items
# [Worker 6] Page 835 scraped, 20 new items
#
# [Worker 3] Page 836 scraped, 20 new items
# [Worker 2] Page 837 scraped, 20 new items
# [Worker 1] Page 839 scraped, 20 new items
# [Worker 5] Page 840 scraped, 20 new items
# [Worker 4] Page 841 scraped, 20 new items
# [Worker 2] Page 845 scraped, 20 new items
# [Worker 6] Page 844 scraped, 20 new items
# [Worker 3] Page 843 scraped, 20 new items
# [Worker 7] Page 842 scraped, 20 new items
# [Worker 1] Page 846 scraped, 20 new items
# [Worker 5] Page 847 scraped, 20 new items
# [Worker 4] Page 848 scraped, 20 new items
# [Worker 2] Page 849 scraped, 20 new items
# [Worker 6] Page 850 scraped, 20 new items
# [Worker 3] Page 851 scraped, 20 new items
# [Worker 7] Page 852 scraped, 20 new items
# [Worker 1] Page 853 scraped, 20 new items
# [Worker 5] Page 854 scraped, 20 new items
# [Worker 7] Page 859 scraped, 20 new items
# [Worker 6] Page 857 scraped, 20 new items
# [Worker 4] Page 855 scraped, 20 new items
# [Worker 3] Page 858 scraped, 20 new items
# [Worker 2] Page 856 scraped, 20 new items
# [Worker 1] Page 860 scraped, 20 new items
# [Worker 5] Page 861 scraped, 20 new items
# [Worker 3] Page 865 scraped, 20 new items
# [Worker 4] Page 864 scraped, 20 new items
# [Worker 6] Page 863 scraped, 20 new items
# [Worker 2] Page 866 scraped, 20 new items
# [Worker 7] Page 862 scraped, 20 new items
# [Worker 1] Page 867 scraped, 20 new items
# [Worker 5] Page 868 scraped, 20 new items
# [Worker 3] Page 869 scraped, 20 new items
# [Worker 4] Page 870 scraped, 20 new items
# [Worker 6] Page 871 scraped, 20 new items
# [Worker 2] Page 872 scraped, 20 new items
# [Worker 7] Page 873 scraped, 20 new items
# [Worker 1] Page 874 scraped, 20 new items
# [Worker 5] Page 875 scraped, 20 new items
# [Worker 3] Page 876 scraped, 20 new items
# [Worker 7] Page 880 scraped, 20 new items
# [Worker 6] Page 878 scraped, 20 new items
# [Worker 2] Page 879 scraped, 20 new items
# [Worker 4] Page 877 scraped, 20 new items
# [Worker 1] Page 881 scraped, 20 new items
# [Worker 5] Page 882 scraped, 20 new items
# [Worker 3] Page 883 scraped, 20 new items
# [Worker 7] Page 884 scraped, 20 new items
# [Worker 6] Page 885 scraped, 20 new items
# [Worker 4] Page 887 scraped, 20 new items
# [Worker 2] Page 886 scraped, 20 new items
# [Worker 1] Page 888 scraped, 20 new items
# [Worker 5] Page 889 scraped, 20 new items
# [Worker 3] Page 890 scraped, 20 new items
# [Worker 7] Page 891 scraped, 20 new items
# [Worker 6] Page 892 scraped, 20 new items
# [Worker 4] Page 893 scraped, 20 new items
# [Worker 2] Page 894 scraped, 20 new items
# [Worker 1] Page 895 scraped, 20 new items
# [Worker 5] Page 896 scraped, 20 new items
# [Worker 3] Page 897 scraped, 20 new items
# [Worker 7] Page 898 scraped, 20 new items
# [Worker 6] Page 899 scraped, 20 new items
# [Worker 4] Page 900 scraped, 20 new items
# [Worker 2] Page 901 scraped, 20 new items
# [Worker 1] Page 902 scraped, 20 new items
# [Worker 5] Page 903 scraped, 20 new items
# [Worker 3] Page 904 scraped, 20 new items
# [Worker 6] Page 906 scraped, 20 new items
# [Worker 4] Page 907 scraped, 20 new items
# [Worker 7] Page 905 scraped, 20 new items
# [Worker 2] Page 908 scraped, 20 new items
# [Worker 1] Page 909 scraped, 20 new items
# [Worker 3] Page 911 scraped, 20 new items
# [Worker 5] Page 910 scraped, 20 new items
# [Worker 4] Page 913 scraped, 20 new items
# [Worker 6] Page 912 scraped, 20 new items
# [Worker 7] Page 914 scraped, 20 new items
# [Worker 2] Page 915 scraped, 20 new items
# [Worker 1] Page 916 scraped, 20 new items
# [Worker 3] Page 917 scraped, 20 new items
# [Worker 5] Page 918 scraped, 20 new items
# [Worker 4] Page 919 scraped, 20 new items
# [Worker 7] Page 921 scraped, 20 new items
# [Worker 6] Page 920 scraped, 20 new items
# [Worker 2] Page 922 scraped, 20 new items
# [Worker 1] Page 923 scraped, 20 new items
# [Worker 3] Page 924 scraped, 20 new items
# [Worker 5] Page 925 scraped, 20 new items
# [Worker 7] Page 927 scraped, 20 new items
# [Worker 6] Page 928 scraped, 20 new items
# [Worker 4] Page 926 scraped, 20 new items
# [Worker 2] Page 929 scraped, 20 new items
# [Worker 1] Page 930 scraped, 20 new items
# [Worker 3] Page 931 scraped, 20 new items
# [Worker 5] Page 932 scraped, 20 new items
# [Worker 4] Page 935 scraped, 20 new items
# [Worker 7] Page 933 scraped, 20 new items
# [Worker 6] Page 934 scraped, 20 new items
# [Worker 2] Page 936 scraped, 20 new items
# [Worker 1] Page 937 scraped, 20 new items
# [Worker 5] Page 939 scraped, 20 new items
# [Worker 3] Page 938 scraped, 20 new items
# [Worker 7] Page 941 scraped, 20 new items
# [Worker 6] Page 942 scraped, 20 new items
# [Worker 4] Page 940 scraped, 20 new items
# [Worker 2] Page 943 scraped, 20 new items
# [Worker 1] Page 944 scraped, 20 new items
# [Worker 3] Page 946 scraped, 20 new items
# [Worker 5] Page 945 scraped, 20 new items
# [Worker 7] Page 947 scraped, 20 new items
# [Worker 4] Page 949 scraped, 20 new items
# [Worker 6] Page 948 scraped, 20 new items
# [Worker 2] Page 950 scraped, 20 new items
# [Worker 1] Page 951 scraped, 20 new items
# [Worker 5] Page 953 scraped, 20 new items
# [Worker 3] Page 952 scraped, 20 new items
# [Worker 6] Page 956 scraped, 20 new items
# [Worker 2] Page 957 scraped, 20 new items
# [Worker 4] Page 955 scraped, 20 new items
# [Worker 7] Page 954 scraped, 20 new items
# [Worker 1] Page 958 scraped, 20 new items
# [Worker 5] Page 959 scraped, 20 new items
# [Worker 3] Page 960 scraped, 20 new items
# [Worker 2] Page 962 scraped, 20 new items
# [Worker 6] Page 961 scraped, 20 new items
# [Worker 4] Page 963 scraped, 20 new items
# [Worker 7] Page 964 scraped, 20 new items
# [Worker 1] Page 965 scraped, 20 new items
# [Worker 5] Page 966 scraped, 20 new items[Worker 3] Page 967 scraped, 20 new items
#
# [Worker 7] Page 971 scraped, 20 new items
# [Worker 2] Page 968 scraped, 20 new items
# [Worker 1] Page 972 scraped, 20 new items
# [Worker 6] Page 969 scraped, 20 new items
# [Worker 4] Page 970 scraped, 20 new items
# [Worker 5] Page 973 scraped, 20 new items
# [Worker 3] Page 974 scraped, 20 new items
# [Worker 4] Page 979 scraped, 20 new items
# [Worker 1] Page 977 scraped, 20 new items
# [Worker 6] Page 978 scraped, 20 new items
# [Worker 7] Page 975 scraped, 20 new items
# [Worker 2] Page 976 scraped, 20 new items
# [Worker 5] Page 980 scraped, 20 new items
# [Worker 3] Page 981 scraped, 20 new items
# [Worker 7] Page 985 scraped, 20 new items
# [Worker 6] Page 984 scraped, 20 new items
# [Worker 1] Page 983 scraped, 20 new items
# [Worker 2] Page 986 scraped, 20 new items
# [Worker 4] Page 982 scraped, 20 new items
# [Worker 3] Page 988 scraped, 20 new items
# [Worker 5] Page 987 scraped, 20 new items
# [Worker 6] Page 990 scraped, 20 new items
# [Worker 4] Page 993 scraped, 20 new items
# [Worker 2] Page 991 scraped, 20 new items
# [Worker 7] Page 989 scraped, 20 new items
# [Worker 1] Page 992 scraped, 20 new items
# [Worker 5] Page 995 scraped, 20 new items
# [Worker 3] Page 994 scraped, 20 new items
# [Worker 6] Page 996 scraped, 20 new items
# [Worker 2] Page 998 scraped, 20 new items
# [Worker 7] Page 999 scraped, 20 new items
# [Worker 4] Page 997 scraped, 20 new items
# [Worker 1] Page 1000 scraped, 20 new items
# [Worker 3] Page 1002 has no adverts, stopping scraper
# [Worker 5] Page 1001 has no adverts, stopping scraper
# [Worker 7] Page 1005 has no adverts, stopping scraper
# [Worker 4] Page 1006 has no adverts, stopping scraper
# [Worker 6] Page 1003 has no adverts, stopping scraper
# [Worker 2] Page 1004 has no adverts, stopping scraper
# [Worker 1] Page 1007 has no adverts, stopping scraper
# Scraping completed: 19878 products collected
